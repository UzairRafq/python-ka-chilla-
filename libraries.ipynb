# %% [markdown]
# *LIBRARIES*

# %%
1. pandas-
2. numpy
3. matplotlib
4. seaborn
5. plotly
6. scipy
7. scikit-learn
8. streamlit

# %%
# pandas numpy matplotlib seaborn plotlyip install

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as px
import seaborn as sns

# %%
# plotting
import seaborn as sns
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "WS2", "WS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="b", order=clarity_ranking,
              scale="linear", data=diamonds)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# C:\Users\hp\AppData\Local\Temp\ipykernel_9364\1068475789.py:8: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x="clarity", y="carat",
# <Axes: xlabel='clarity', ylabel='carat'>
